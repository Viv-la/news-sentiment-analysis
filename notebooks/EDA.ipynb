# %%
plt.plot(df['Date'], df['Daily_Return'])

plt.title("Daily Stock Returns")
plt.xlabel("Date")
plt.ylabel("Daily Return (%)")

plt.xticks(rotation=45)

plt.show()

# %%
df[['Date', 'Close', 'Daily_Return']].head()
# Out:
#         Date   Close  Daily_Return
# 0 2024-01-02  185.85           NaN
# 1 2024-01-03  184.25     -0.860909
# 2 2024-01-04  181.91     -1.270014
# 3 2024-01-05  181.18     -0.401297
# 4 2024-01-08  185.56      2.417485

# %%
df['Daily_Return'] = df['Close'].pct_change() * 100

# %%
plt.plot(df['Date'], df['Volume'])

plt.title("Trading Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")

plt.xticks(rotation=45)

plt.show()

# %%
plt.plot(df['Date'], df['Close'])

plt.title("Stock Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")

plt.xticks(rotation=45)

plt.show()

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12,6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    30 non-null     datetime64[us]
#  1   Open    29 non-null     float64
#  2   High    30 non-null     float64
#  3   Low     30 non-null     float64
#  4   Close   29 non-null     float64
#  5   Volume  30 non-null     int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 1.5 KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count   29.000000   30.000000   30.000000   29.000000  3.000000e+01
# mean   187.113103  188.631667  186.024667  187.953793  5.278999e+07
# std      4.420964    4.397430    4.405870    4.137399  1.607782e+07
# min    181.270000  182.750000  180.170000  181.180000  2.808250e+07
# 25%    183.920000  185.670000  182.890000  185.140000  4.300385e+07
# 50%    186.090000  187.150000  184.610000  186.920000  5.317910e+07
# 75%    189.330000  192.137500  189.247500  191.560000  5.896200e+07
# max    196.880000  197.200000  194.760000  196.100000  9.715210e+07

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      1
# High      0
# Low       0
# Close     1
# Volume    0
# dtype: int64

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nfepo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
df = pd.read_csv("../data/raw/sample_stocks.csv")

df.head()
# Out:
#          Date    Open    High     Low   Close    Volume
# 0  2024-01-02  186.09  187.50  184.22  185.85  82488700
# 1  2024-01-03  184.22  185.88  183.43  184.25  58414500
# 2  2024-01-04  182.15  183.09  180.63  181.91  71983500
# 3  2024-01-05  181.99  182.75  180.17  181.18  62099900
# 4  2024-01-08  182.09  185.60  181.34  185.56  59144500

# %%
df = pd.read_csv("../data/raw/sample_stocks.csv")

df.head()
# Out:
#          Date    Open    High     Low   Close    Volume
# 0  2024-01-02  186.09  187.50  184.22  185.85  82488700
# 1  2024-01-03  184.22  185.88  183.43  184.25  58414500
# 2  2024-01-04  182.15  183.09  180.63  181.91  71983500
# 3  2024-01-05  181.99  182.75  180.17  181.18  62099900
# 4  2024-01-08  182.09  185.60  181.34  185.56  59144500

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    30 non-null     str
#  1   Open    29 non-null     float64
#  2   High    30 non-null     float64
#  3   Low     30 non-null     float64
#  4   Close   29 non-null     float64
#  5   Volume  30 non-null     int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 1.5 KB

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='str')

# %%
df.shape
# Out:
# (30, 6)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.corpus import stopwords

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# # Financial News Sentiment Analysis
#
# ## Exploratory Data Analysis (EDA)
#
# This notebook explores financial news headlines to uncover:
# - publication trends
# - publisher activity
# - headline patterns
# - topic distributions
# - early sentiment indicators
